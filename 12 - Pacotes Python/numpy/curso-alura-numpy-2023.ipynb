# %% [markdown]
# # Curso Numpy

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np

# %% [markdown]
# ## Importando dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'

dados = np.loadtxt(url,delimiter=',',usecols=np.arange(1,88))

# %% [markdown]
# ## Exploração dos dados

# %%
dados.ndim
# Out:
# 2

# %%
dados.size
# Out:
# 522

# %%
dados.shape
# Out:
# (6, 87)

# %%
dado_tranposto = dados.T

# %%
datas = dado_tranposto[:,0]

# %%
precos = dado_tranposto[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88)

# %%
plt.plot(datas,precos[:,0])

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow_ano1 = Moscow[0:12] 
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
Moscow_ano1
# Out:
# array([79.72, 81.08, 79.68, 79.8 , 80.63, 80.8 , 80.28, 78.99, 76.77,
#        76.09, 76.36, 77.16])

# %%
plt.plot(np.arange(1,13,1),Moscow_ano1)
plt.plot(np.arange(1,13,1),Moscow_ano2)
plt.plot(np.arange(1,13,1),Moscow_ano3)
plt.plot(np.arange(1,13,1),Moscow_ano4)
plt.legend(['ano1','ano2','ano3','ano4'])

# %%
np.array_equal(Moscow_ano3,Moscow_ano4)
# Out:
# False

# %%
np.allclose(Moscow_ano3,Moscow_ano4,10)
# Out:
# True

# %%
plt.plot(datas, Kaliningrad)

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
np.isnan(Kaliningrad).sum()
# Out:
# 1

# %%
(Kaliningrad[3] + Kaliningrad[5]) / 2
# Out:
# 49.17

# %%
np.mean([Kaliningrad[3],Kaliningrad[5]])
# Out:
# 49.17

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3],Kaliningrad[5]])

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kaliningrad)
# Out:
# 74.5506896551724

# %% [markdown]
# ## 3 Operações entre arrays

# %%
plt.plot(datas,Moscow)

# %% [markdown]
# $$ y = ax + b $$

# %%
x = datas
y=2*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %% [markdown]
# Encontrando uma hipótes de equação da reta:
# 1. Diferença do Original com a Hipótese
# 2. Elevar ao quadrado
# 3. Somar
# 4. Rais quadrada

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
y = 0.52*x +80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %% [markdown]
# ### Encontrando o coeficiente angular e linear

# %%
X = datas
Y = Moscow
n = np.size(Moscow)

# %%
n
# Out:
# 87

# %%
(X**2).shape
# Out:
# (87,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)

a
# Out:
# 0.43520212145512926

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = np.mean(Y) - a*np.mean(X)
b
# Out:
# 79.64892274792834

# %%
y = a*X+b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %% [markdown]
# ### Coeficiente a e b com Numpy

# %%
np.polyfit(X, Y,1)
# Out:
# array([ 0.43520212, 79.64892275])

# %%
a = np.polyfit(X, y,1)[0]
b = np.polyfit(X, y,1)[0]

# %%
(41.5*a)+b
# Out:
# 18.49609016184298

# %%
X=datas
Y=Moscow
a = np.polyfit(X, y,1)[0]
b = np.polyfit(X, y,1)[1]
y = a*X+b

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(41.5,41.5*a+b,'*r')

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(100,100*a+b,'*r')

# %% [markdown]
# ## 4 Números aleatórios

# %%
np.random.randint(low=40,high=100,size=100)
# Out:
# array([76, 97, 54, 99, 88, 65, 53, 70, 87, 85, 70, 54, 89, 87, 87, 94, 45,
#        96, 98, 64, 97, 79, 89, 53, 72, 97, 54, 64, 52, 82, 82, 61, 92, 68,
#        87, 97, 67, 88, 90, 75, 53, 85, 85, 89, 78, 60, 77, 42, 99, 43, 66,
#        49, 83, 66, 65, 94, 64, 81, 74, 83, 81, 58, 54, 88, 41, 74, 56, 48,
#        98, 58, 64, 44, 78, 57, 96, 82, 74, 71, 92, 59, 62, 61, 61, 65, 89,
#        74, 86, 74, 79, 48, 62, 49, 89, 99, 88, 65, 58, 52, 57, 62])

# %%
np.random.uniform(low=0.10,high=0.90,size=100)
# Out:
# array([0.17048168, 0.22032304, 0.32914695, 0.8761481 , 0.16518574,
#        0.57011422, 0.54030703, 0.68337521, 0.37518513, 0.63220016,
#        0.15172646, 0.2742737 , 0.2237366 , 0.39592399, 0.48802385,
#        0.61194283, 0.3379959 , 0.89194207, 0.21585221, 0.82765385,
#        0.85723634, 0.25296886, 0.50543435, 0.89956314, 0.59331058,
#        0.65415763, 0.82282164, 0.55766909, 0.38067034, 0.378616  ,
#        0.52761127, 0.77639596, 0.62967497, 0.59470744, 0.55060792,
#        0.19640561, 0.32974833, 0.19419788, 0.31459407, 0.4902944 ,
#        0.72376175, 0.40020274, 0.53214658, 0.55458093, 0.73186312,
#        0.16353154, 0.16323137, 0.52477397, 0.43493021, 0.54123606,
#        0.42396468, 0.30106772, 0.7676561 , 0.83486629, 0.79253933,
#        0.52722274, 0.79822159, 0.3260595 , 0.52649019, 0.14066514,
#        0.2617776 , 0.21760609, 0.74506525, 0.77933762, 0.52999249,
#        0.56980988, 0.22390482, 0.88856326, 0.85716217, 0.49133436,
#        0.18080021, 0.66986005, 0.3786716 , 0.67454016, 0.70464448,
#        0.86647556, 0.25261738, 0.57324721, 0.53296991, 0.26632026,
#        0.79863289, 0.72273276, 0.81608602, 0.6663862 , 0.10796306,
#        0.18784876, 0.37326742, 0.12072055, 0.60498158, 0.30128529,
#        0.65772516, 0.47608882, 0.70887411, 0.10912662, 0.49268117,
#        0.17098469, 0.77095355, 0.5557081 , 0.1997272 , 0.63363036])

# %%
coef_angulares = np.random.uniform(low=0.10,high=0.90,size=100)

# %%
norma = np.array([])
for i in range(100):
    norma = np.append(norma,np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
norma
# Out:
# array([165.55066826, 167.59978411, 119.07236165, 185.29038341,
#        141.29016538, 118.82526902, 210.36025058, 201.47443304,
#        160.92003622, 132.73827676, 170.18673432, 166.93738828,
#        222.27205032, 117.77120023, 122.65537683, 132.13315865,
#        170.67855686, 219.10342139, 140.36724247, 105.06005645,
#        128.22829373, 219.05448705, 131.53068099, 104.76249606,
#        117.5287921 , 173.19339599, 103.65892719, 180.52542742,
#        212.96608595, 175.63868532, 215.72165332, 137.32136533,
#        148.29583463, 130.822985  , 158.71408931, 151.1326595 ,
#        239.48309774, 117.76613191, 161.44796524, 188.34442321,
#        184.18796384, 197.134003  , 130.28728721, 108.14825656,
#        181.43593872, 203.41641515, 121.81693565, 142.44627785,
#        189.03720726, 185.88446259, 149.60576612, 209.28290274,
#        183.4005365 , 139.14724806, 179.15525656, 185.32501014,
#        221.38218984, 155.35998659, 103.57988797, 185.1658601 ,
#        120.17305377, 122.37667804, 126.33364111, 130.67402169,
#        143.83536615, 125.18784224, 112.27601296, 131.04786014,
#        161.60055229, 112.59587846, 105.18329416, 116.88440958,
#        173.06005238, 183.43228368, 191.85342408, 125.78370319,
#        105.04816087, 128.15808293, 102.04566265, 170.13753639,
#        142.84905212, 103.06324294, 116.00390706, 165.14169163,
#        125.60781819, 173.79715545, 106.99791242, 113.15215729,
#        161.0849229 , 117.83091048, 214.52733287, 237.84840767,
#        145.23730823, 105.33942702, 223.15586134, 172.59006353,
#        164.95891807, 104.85758434, 192.33835668, 155.89364636])

# %%
coef_angulares[1]
# Out:
# 0.7169587170761159
