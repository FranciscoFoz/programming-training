# %% [markdown]
# # Importando JSON - DOAB

# %%
from urllib.request import urlopen, Request
from urllib.request import URLError, HTTPError
import json
import pandas as pd

pd.options.display.max_columns = 999
pd.options.display.max_info_rows = 999

# %% [markdown]
# Página

# %% [markdown]
# https://directory.doabooks.org/rest/search?query=%22data+science%22&expand=metadata

# %% [markdown]
# ## Funções

# %%
def assunto_url(assunto):
    '''
    Esta função recebe um assunto como entrada e retorna uma URL para fazer uma pesquisa desse assunto na API do DOAB. 
    
    assunto = string entre aspas duplas (ex.: "data science")
    '''
    assunto = assunto.replace(' ', '+')
    url = f'https://directory.doabooks.org/rest/search?query={assunto}&expand=metadata'
    return url


def resposta_json(url):
    '''
    Esta função recebe uma URL como entrada, faz uma solicitação HTTP usando o cabeçalho armazenado na variável de instância headers, 
    lê a resposta HTTP e retorna o JSON da resposta.
    '''
    try: 
        req = Request(url)
        response = urlopen(req)
        json = response.read()
    except HTTPError as e:
        print(e.status, e.reason)
    except URLError as e:
        print(e.reason)
    return json

# %%
url_assunto_doab = assunto_url('"data science"')
doab_resposta_json = resposta_json(url_assunto_doab)

# %%
data = json.loads(doab_resposta_json)

# %%
data = json.loads(doab_resposta_json)
# para cada item na lista, crie um novo dicionário com as chaves de 'metadata' como chaves principais
for item in data:
    metadata = {}
    for meta in item['metadata']:
        metadata[meta['key']] = meta['value']
    # exclua a chave 'metadata' e adicione o novo dicionário ao objeto principal
    del item['metadata']
    item.update(metadata)

# imprima o resultado
data
# Out:
# [{'uuid': '1bf138c9-ac0d-4a66-b7a7-480df06f6361',
#   'name': 'Data Science, Data Visualization, and Digital Twins',
#   'handle': '20.500.12854/90154',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-07-27 08:13:34.118',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/1bf138c9-ac0d-4a66-b7a7-480df06f6361',
#   'dc.contributor.editor': 'Shirowzhan, Sara',
#   'dc.date.accessioned': '2022-07-27T08:13:33Z',
#   'dc.date.available': '2022-07-27T08:13:33Z',
#   'dc.date.issued': '2022',
#   'dc.identifier': 'ONIX_20220727_9781839629440_50',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/90154',
#   'dc.description.abstract': 'Real-time, web-based, and interactive visualisations are proven to be outstanding methodologies and tools in numerous fields when knowledge in sophisticated data science and visualisation techniques is available. The rationale for this is because modern data science analytical approaches like machine/deep learning or artificial intelligence, as well as digital twinning, promise to give data insights, enable informed decision-making, and facilitate rich interactions among stakeholders.The benefits of data visualisation, data science, and digital twinning technologies motivate this book, which exhibits and presents numerous developed and advanced data science and visualisation approaches. Chapters cover such topics as deep learning techniques, web and dashboard-based visualisations during the COVID pandemic, 3D modelling of trees for mobile communications, digital twinning in the mining industry, data science libraries, and potential areas of future data science development.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::U Computing & information technology::UM Computer programming / software development::UML Graphics programming',
#   'dc.subject.other': 'Graphics programming',
#   'dc.title': 'Data Science, Data Visualization, and Digital Twins',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.5772/intechopen.87794',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25750',
#   'publisher.contact': 'Slobodan Momčilović',
#   'publisher.name': 'IntechOpen',
#   'publisher.email': 'ai@intechopen.com',
#   'publisher.address': 'IntechOpen Limited The Shard, 25th floor 32 London Bridge Street London, SE1 9SG',
#   'publisher.country': 'United Kingdom',
#   'publisher.website': 'https://www.intechopen.com/',
#   'publisher.oabooks.exampleUrl': 'https://www.intechopen.com/books/infective-endocarditis',
#   'publisher.oalicense': 'All published book chapters are licensed under a Creative Commons Attribution 3.0 Unported License. Monographs are licensed under the Creative Commons Attribution-NonCommercial 4.0 International (CC BY-NC 4.0) license. Our Copyright Policy aims to guarantee that original material is published while at the same time giving significant freedom to our authors. IntechOpen upholds a flexible copyright policy meaning that there is no copyright transfer to the publisher and authors hold exclusive copyright to their work. <P> https://www.intechopen.com/page/copyright-policy',
#   'publisher.peerreviewpolicy': "Review for Edited Volumes <P> All submitted manuscripts are subject to a review to ensure that they comply with the scientific and ethical requirements. Book chapter manuscripts are submitted to IntechOpen as contributions to Edited Volumes. All chapters undergo a main Editor peer-review. Academic Editors' chapters undergo external blind peer-review – the result is a fully peer-reviewed book. <P> Book chapters go through a two-step review process: chapter proposal review and full chapter review. The Academic Editor reviews all chapter proposals, decides which topics to focus on, suggests improvements and selects potential manuscripts with a high degree of relevance and bearing on developments within the field. Academic Editors have the overall responsibility for the content of the publication. Chapters that do not fall within the scope and topics of the book, are scientifically not sound, are incomplete, or of marginal interest to the field are rejected. <P> Once submitted, the Academic Editor(s) reviews the full chapters, too, by screening them for plagiarism, evaluating their scientific merit, and ultimately decides whether they are suitable for inclusion in the book or not. <P> During the review process the Academic Editor(s) suggest rounds of revision and authors work on improving their chapters. The Academic Editor(s) has/have the absolute possibility of accepting, requesting major or minor revisions, or rejecting the full chapter submissions at any point. <P> Review for Monographs <P> Each submitted manuscript undergoes a plagiarism check and enters a peer-review process afterward. Referees for monographs are external collaborators who agreed to contribute their own expertise in reviewing the submitted manuscript, independently and on a voluntary basis. <P> https://www.intechopen.com/page/peer-reviewing",
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.intechopen.com/how-open-access-publishing-with-intechopen-works',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.intechopen.com/page/OA-publishing-fees',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1692',
#   'publisher.phone': '+44 20 8089 5701',
#   'publisher.description': 'Founded in 2004, IntechOpen, the first native scientific publisher of Open Access books, provides a collaborative environment for peer-reviewed scholarly content and book publishing of academic research. <P> IntechOpen is currently the world’s leading publisher of Open Access books, with over 4,200 published volumes to date. The publishing program consists of the following formats: complete monographs (long-form manuscripts that allow authors to focus on presenting a single subject or a specific aspect of that subject); edited volumes/collections (authors contribute a scientific book chapter); and IntechOpen Compacts (shorter-length monographs). Authors are encouraged to find the best home for their work, whether this is via a direct invitation, or by proposing their own volume. <P> We are passionate about the quality of research, and all published content is peer-reviewed, copyedited, and subject to a plagiarism check. The Open Access model, which applies to all IntechOpen publications, eliminates subscriptions and paywalls thereby allowing free, immediate access to full text versions of all content. The scientific community of editors, authors, funders, and librarians worldwide benefit from open access research dissemination, ensuring faster sharing and advancement of scientific knowledge.',
#   'oapen.imprint': 'IntechOpen',
#   'oapen.pages': '116'},
#  {'uuid': '4bc545b6-6b71-415b-802e-97add94d4e3f',
#   'name': 'Introduction to Data Science and Machine Learning',
#   'handle': '20.500.12854/67387',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-01-31 16:46:25.117',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/4bc545b6-6b71-415b-802e-97add94d4e3f',
#   'dc.contributor.editor': 'Kadry, Seifedine',
#   'dc.date.accessioned': '2021-04-20T16:12:18Z',
#   'dc.date.available': '2021-04-20T16:12:18Z',
#   'dc.date.issued': '2020',
#   'dc.identifier': 'ONIX_20210420_9781838803346_2746',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/67387',
#   'dc.description.abstract': '“Introduction to Data Science and Machine Learning” has been created with the goal to provide beginners seeking to learn about data science, data enthusiasts, and experienced data professionals with a deep understanding of data science application development using open-source programming from start to finish. This book is divided into four sections: the first section contains an introduction to the book, the second covers the field of data science, software development, and open-source based embedded hardware; the third section covers algorithms that are the decision engines for data science applications; and the final section brings together the concepts shared in the first three sections and provides several examples of data science applications.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::U Computing & information technology::UN Databases::UNF Data mining',
#   'dc.subject.other': 'Data mining',
#   'dc.title': 'Introduction to Data Science and Machine Learning',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.5772/intechopen.77469',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25750',
#   'publisher.contact': 'Slobodan Momčilović',
#   'publisher.name': 'IntechOpen',
#   'publisher.email': 'ai@intechopen.com',
#   'publisher.address': 'IntechOpen Limited The Shard, 25th floor 32 London Bridge Street London, SE1 9SG',
#   'publisher.country': 'United Kingdom',
#   'publisher.website': 'https://www.intechopen.com/',
#   'publisher.oabooks.exampleUrl': 'https://www.intechopen.com/books/infective-endocarditis',
#   'publisher.oalicense': 'All published book chapters are licensed under a Creative Commons Attribution 3.0 Unported License. Monographs are licensed under the Creative Commons Attribution-NonCommercial 4.0 International (CC BY-NC 4.0) license. Our Copyright Policy aims to guarantee that original material is published while at the same time giving significant freedom to our authors. IntechOpen upholds a flexible copyright policy meaning that there is no copyright transfer to the publisher and authors hold exclusive copyright to their work. <P> https://www.intechopen.com/page/copyright-policy',
#   'publisher.peerreviewpolicy': "Review for Edited Volumes <P> All submitted manuscripts are subject to a review to ensure that they comply with the scientific and ethical requirements. Book chapter manuscripts are submitted to IntechOpen as contributions to Edited Volumes. All chapters undergo a main Editor peer-review. Academic Editors' chapters undergo external blind peer-review – the result is a fully peer-reviewed book. <P> Book chapters go through a two-step review process: chapter proposal review and full chapter review. The Academic Editor reviews all chapter proposals, decides which topics to focus on, suggests improvements and selects potential manuscripts with a high degree of relevance and bearing on developments within the field. Academic Editors have the overall responsibility for the content of the publication. Chapters that do not fall within the scope and topics of the book, are scientifically not sound, are incomplete, or of marginal interest to the field are rejected. <P> Once submitted, the Academic Editor(s) reviews the full chapters, too, by screening them for plagiarism, evaluating their scientific merit, and ultimately decides whether they are suitable for inclusion in the book or not. <P> During the review process the Academic Editor(s) suggest rounds of revision and authors work on improving their chapters. The Academic Editor(s) has/have the absolute possibility of accepting, requesting major or minor revisions, or rejecting the full chapter submissions at any point. <P> Review for Monographs <P> Each submitted manuscript undergoes a plagiarism check and enters a peer-review process afterward. Referees for monographs are external collaborators who agreed to contribute their own expertise in reviewing the submitted manuscript, independently and on a voluntary basis. <P> https://www.intechopen.com/page/peer-reviewing",
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.intechopen.com/how-open-access-publishing-with-intechopen-works',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.intechopen.com/page/OA-publishing-fees',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1692',
#   'publisher.phone': '+44 20 8089 5701',
#   'publisher.description': 'Founded in 2004, IntechOpen, the first native scientific publisher of Open Access books, provides a collaborative environment for peer-reviewed scholarly content and book publishing of academic research. <P> IntechOpen is currently the world’s leading publisher of Open Access books, with over 4,200 published volumes to date. The publishing program consists of the following formats: complete monographs (long-form manuscripts that allow authors to focus on presenting a single subject or a specific aspect of that subject); edited volumes/collections (authors contribute a scientific book chapter); and IntechOpen Compacts (shorter-length monographs). Authors are encouraged to find the best home for their work, whether this is via a direct invitation, or by proposing their own volume. <P> We are passionate about the quality of research, and all published content is peer-reviewed, copyedited, and subject to a plagiarism check. The Open Access model, which applies to all IntechOpen publications, eliminates subscriptions and paywalls thereby allowing free, immediate access to full text versions of all content. The scientific community of editors, authors, funders, and librarians worldwide benefit from open access research dissemination, ensuring faster sharing and advancement of scientific knowledge.',
#   'oapen.imprint': 'IntechOpen',
#   'oapen.pages': '232'},
#  {'uuid': '2538f19b-32c9-45f7-838f-655f6d78127f',
#   'name': 'Collaborative Technologies and Data Science in Artificial Intelligence Applications',
#   'handle': '20.500.12854/64403',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-01-31 09:42:15.642',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/2538f19b-32c9-45f7-838f-655f6d78127f',
#   'dc.contributor.editor': 'Luther, Wolfram',
#   'dc.date.accessioned': '2021-04-08T15:07:01Z',
#   'dc.date.available': '2021-04-08T15:07:01Z',
#   'dc.date.issued': '2020',
#   'dc.identifier': 'ONIX_20210408_9783832551414_102',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/64403',
#   'dc.description.abstract': "In September 2020, researchers from Armenia, Chile, Germany and Japan met at the American University of Armenia for a virtual conference to discuss technologies with applications in smart cities, data science and information theory approaches for intelligent systems, technical challenges for intelligent environments, smart human centered computing, artificial neural networks, and deep learning. This book presents their contributions to the 2nd CODASSCA workshop on collaborative technologies and data science in artificial intelligence applications, a highly topical issue in today's computer science.",
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::U Computing & information technology::UB Information technology: general issues',
#   'dc.subject.other': 'Smart human centered computing',
#   'dc.title': 'Collaborative Technologies and Data Science in Artificial Intelligence Applications',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.30819/5141',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/64232',
#   'publisher.name': 'Logos Verlag Berlin',
#   'oapen.imprint': 'Logos Verlag Berlin',
#   'oapen.pages': '200',
#   'oapen.place.publication': 'Berlin/Germany'},
#  {'uuid': 'cab18294-da6f-49d7-80f1-f3951f5d70c2',
#   'name': 'Regulatory Data Science for Medical Devices',
#   'handle': '20.500.12854/81053',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-05-06 11:24:47.124',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/cab18294-da6f-49d7-80f1-f3951f5d70c2',
#   'dc.contributor.editor': 'Bergmann, Jeroen',
#   'dc.date.accessioned': '2022-05-06T11:24:45Z',
#   'dc.date.available': '2022-05-06T11:24:45Z',
#   'dc.date.issued': '2022',
#   'dc.identifier': 'ONIX_20220506_9783036538938_119',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/81053',
#   'dc.description.abstract': 'Regulations that cover the legal obligations that manufacturers are bound to are essential for keeping the general public safe. Companies need to follow the regulations in order to bring their products to market. A good understanding of the regulations and the regulatory pathway defines how fast and at what cost the manufacturer can introduce innovations to the market. Regulatory technology and data science can lead to new regulatory processes and evidence in the medical field. It can equip stakeholders with unique tools that can make regulatory decisions more objective, efficient, and accurate. This book describes the latest research within the broader domain of Medical Regulatory Technology (MedRegTech). It covers concepts such as the complexity and user-friendliness of medical device regulations, novel algorithms for regulatory navigation, descriptive datasets from a health service provider, regulatory data science techniques, and considerations of the environmental impacts within a national health service. This book brings all these aspects together to offer an introduction into MedRegTech research. In the long term, these technologies and methods will help optimize the regulatory strategy for individual healthcare innovations and revolutionize the way we engage with regulatory services.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::T Technology, engineering, agriculture::TB Technology: general issues::TBX History of engineering & technology',
#   'dc.subject.other': 'n/a',
#   'dc.title': 'Regulatory Data Science for Medical Devices',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-3894-5',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
#   'publisher.website': 'www.mdpi.com/books',
#   'publisher.oabooks.exampleUrl': 'http://www.mdpi.com/books/pdfview/book/735',
#   'publisher.oalicense': 'Unless otherwise agreed, edited books (book as a whole) are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY-NC-ND) license. The license allows users to download, copy, and build upon published work non-commercially, as long as the author and publisher are properly credited. If the material is transformed or built upon, the resulting work may not be distributed. The source of the published text must be identified and the DOI of the book should be given. Unless otherwise agreed, articles and monographs are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY) license. The “Open Access” license allows unlimited distribution and reuse as long as appropriate credit is given to the original source and any changes made compared to the original are indicated. The source of the published text must be identified and the DOI of the article should be given.',
#   'publisher.peerreviewpolicy': 'MDPI Books is dedicated to high-quality scholarly publishing. Thus, all manuscripts submitted to MDPI Books are thoroughly reviewed by experts prior to publication. MDPI Books arranges the review process for editions in coordination with the academic editors and coordinates review for monographs with reviewers from the MDPI network. The final decision regarding acceptance of a manuscript lies with the academic editor for Editions and the MDPI Books academic consultant for monographs. <BR><BR> Pre-Check Immediately after submission, manuscripts are checked by MDPI Books editorial staff. You may receive feedback at this stage, prior to peer review. At this stage, checks will be made for plagiarism, data falsification, reuse permissions for figures, inappropriate authorship credit, etc. MDPI takes publishing ethics issues very seriously and adheres to the guidelines of the Committee on Publication Ethics (COPE). <BR><BR> Review All manuscripts submitted to MDPI Books are reviewed by experts from the relevant field. Authors may suggest potential referees with the appropriate expertise, but note that the editors may not necessarily approach these referees. <BR><BR> MDPI aims to provide an efficient and high quality publishing service to authors and to the scientific community. Thus, we ask reviewers to assist by providing review reports in a timely manner—for Editions: several weeks, for monographs: several months. <BR><BR> Authors will typically be asked to revise their manuscript prior to a final editorial decision. <BR> Editor Decision When making an editorial recommendation, reviewers can select from: <BR> accept minor revision major revision reject <BR><BR> The Academic Editor makes an assessment based on the suitability of selected reviewers, the adequacy of reviewer comments and author response, and the overall scientific quality of the paper. <BR><BR> URL: http://www.mdpi.com/books/publish_with_us',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1222',
#   'publisher.phone': '0041 61 683 77 34',
#   'publisher.description': 'With over two decades of academic publishing experience, MDPI is a leader in open access publishing. With its Books Initiative, MDPI also supports new paths in book publishing. MDPI Books offers quality open access book publishing to promote the exchange of ideas and knowledge across all disciplines in a globalized world. MDPI Books encompasses all the benefits of open access—high availability and visibility, as well as wide and rapid dissemination across all book formats. <BR><BR> URL: http://www.mdpi.com/books',
#   'oapen.pages': '76',
#   'oapen.place.publication': 'Basel'},
#  {'uuid': 'c55436b4-5501-420a-93e7-3355117d1ed8',
#   'name': 'Principles and Applications of Data Science',
#   'handle': '20.500.12854/87513',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-07-06 11:53:51.81',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/c55436b4-5501-420a-93e7-3355117d1ed8',
#   'dc.contributor.editor': 'Liu, Chuan-Ming',
#   'dc.date.accessioned': '2022-07-06T11:53:50Z',
#   'dc.date.available': '2022-07-06T11:53:50Z',
#   'dc.date.issued': '2022',
#   'dc.identifier': 'ONIX_20220706_9783036545271_108',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/87513',
#   'dc.description.abstract': 'Data science is an emerging multidisciplinary field which lies at the intersection of computer science, statistics, and mathematics, with different applications and related to data mining, deep learning, and big data. This Special Issue on “Principles and Applications of Data Science” focuses on the latest developments in the theories, techniques, and applications of data science. The topics include data cleansing, data mining, machine learning, deep learning, and the applications of medical and healthcare, as well as social media.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::T Technology, engineering, agriculture::TB Technology: general issues::TBX History of engineering & technology',
#   'dc.subject.other': 'crop production prediction',
#   'dc.title': 'Principles and Applications of Data Science',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-4528-8',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
#   'publisher.website': 'www.mdpi.com/books',
#   'publisher.oabooks.exampleUrl': 'http://www.mdpi.com/books/pdfview/book/735',
#   'publisher.oalicense': 'Unless otherwise agreed, edited books (book as a whole) are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY-NC-ND) license. The license allows users to download, copy, and build upon published work non-commercially, as long as the author and publisher are properly credited. If the material is transformed or built upon, the resulting work may not be distributed. The source of the published text must be identified and the DOI of the book should be given. Unless otherwise agreed, articles and monographs are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY) license. The “Open Access” license allows unlimited distribution and reuse as long as appropriate credit is given to the original source and any changes made compared to the original are indicated. The source of the published text must be identified and the DOI of the article should be given.',
#   'publisher.peerreviewpolicy': 'MDPI Books is dedicated to high-quality scholarly publishing. Thus, all manuscripts submitted to MDPI Books are thoroughly reviewed by experts prior to publication. MDPI Books arranges the review process for editions in coordination with the academic editors and coordinates review for monographs with reviewers from the MDPI network. The final decision regarding acceptance of a manuscript lies with the academic editor for Editions and the MDPI Books academic consultant for monographs. <BR><BR> Pre-Check Immediately after submission, manuscripts are checked by MDPI Books editorial staff. You may receive feedback at this stage, prior to peer review. At this stage, checks will be made for plagiarism, data falsification, reuse permissions for figures, inappropriate authorship credit, etc. MDPI takes publishing ethics issues very seriously and adheres to the guidelines of the Committee on Publication Ethics (COPE). <BR><BR> Review All manuscripts submitted to MDPI Books are reviewed by experts from the relevant field. Authors may suggest potential referees with the appropriate expertise, but note that the editors may not necessarily approach these referees. <BR><BR> MDPI aims to provide an efficient and high quality publishing service to authors and to the scientific community. Thus, we ask reviewers to assist by providing review reports in a timely manner—for Editions: several weeks, for monographs: several months. <BR><BR> Authors will typically be asked to revise their manuscript prior to a final editorial decision. <BR> Editor Decision When making an editorial recommendation, reviewers can select from: <BR> accept minor revision major revision reject <BR><BR> The Academic Editor makes an assessment based on the suitability of selected reviewers, the adequacy of reviewer comments and author response, and the overall scientific quality of the paper. <BR><BR> URL: http://www.mdpi.com/books/publish_with_us',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1222',
#   'publisher.phone': '0041 61 683 77 34',
#   'publisher.description': 'With over two decades of academic publishing experience, MDPI is a leader in open access publishing. With its Books Initiative, MDPI also supports new paths in book publishing. MDPI Books offers quality open access book publishing to promote the exchange of ideas and knowledge across all disciplines in a globalized world. MDPI Books encompasses all the benefits of open access—high availability and visibility, as well as wide and rapid dissemination across all book formats. <BR><BR> URL: http://www.mdpi.com/books',
#   'oapen.pages': '168',
#   'oapen.place.publication': 'Basel'},
#  {'uuid': '3be88d8d-3fc6-4fa7-82c0-a2549616aa6d',
#   'name': 'Data Sciences: From First-Order Logic to the Web',
#   'handle': '20.500.12854/44554',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-02-01 00:09:07.528',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/3be88d8d-3fc6-4fa7-82c0-a2549616aa6d',
#   'dc.contributor.author': 'Serge Abiteboul',
#   'dc.date.accessioned': '2021-02-11T10:59:05Z',
#   'dc.date.available': '2021-02-11T10:59:05Z',
#   'dc.date.issued': '2012',
#   'dc.date.submitted': '2014-02-27 14:16:29',
#   'dc.identifier': '15780',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/44554',
#   'dc.description.abstract': 'Relational database management systems, using as foundations a formal language, first-order logic, serve as mediators between individuals and machines. With the increase in the volume of data disseminated on the Web, a “collective intelligence” is currently emerging, shaped by large search engines whose monopoly raises ethical and political questions. One of the main challenges for the coming years is the development of technologies that will make it possible to find, evaluate, validate, veri...',
#   'dc.language': 'English',
#   'dc.subject.other': 'algorithm',
#   'dc.title': 'Data Sciences: From First-Order Logic to the Web',
#   'dc.type': 'book',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25371',
#   'publisher.contact': 'Matthieu Andreani',
#   'publisher.name': 'Collège de France',
#   'publisher.email': 'matthieu.andreani@openedition.org',
#   'publisher.country': 'France',
#   'publisher.website': 'http://books.openedition.org/cdf/',
#   'publisher.oalicense': 'All our books are protected by French Law (droits d’auteur). All our open access books are free to read for everybody, without limitation. All our open access books are free to share with our embeddable reader, in any context, without limitation.',
#   'publisher.peerreviewpolicy': 'All books published by the College de France are selected by the Commission of publications (“Commission des publications”), which is directed by the Vice-President of the Assembly of teachers of the College. The books are peer reviewed by two internal reviewers (Professors).',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1199',
#   'publisher.description': 'Le Collège de France répond à une double vocation\xa0: être à la fois le lieu de la recherche la plus audacieuse et celui de son enseignement. Depuis 1530, l’une de ses principales missions est de diffuser la science, la pensée et la recherche nouvelles à mesure qu’elles s’élaborent. Il édite une grande variété de livres\xa0: depuis 1901, un «\xa0annuaire\xa0» qui rend compte, notamment, de l’enseignement annuel de chaque professeur, le texte intégral des leçons inaugurales (depuis 1949), des actes de colloques et monographies originales, ainsi qu’une revue, La Lettre du Collège de France (depuis 2001). Tous ces ouvrages font l’objet d’une édition électronique depuis 2010. Depuis 2003, la collection des leçons inaugurales est en outre publiée en partenariat avec les éditions Fayard, et depuis 1996; certains travaux (colloques, cours, conférences) trouvent leur place dans la collection du Collège de France aux Editions Odile Jacob.'},
#  {'uuid': '2687951a-d1b8-42e4-89f3-81b01d0ecf72',
#   'name': 'Data Feminism',
#   'handle': '20.500.12854/78584',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-02-21 15:12:35.805',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/2687951a-d1b8-42e4-89f3-81b01d0ecf72',
#   'dc.contributor.author': 'Klein, Lauren F.',
#   'dc.date.accessioned': '2022-02-21T15:12:34Z',
#   'dc.date.available': '2022-02-21T15:12:34Z',
#   'dc.date.issued': '2020',
#   'dc.identifier': 'ONIX_20220221_9780262358521_104',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/78584',
#   'dc.description.abstract': "A new way of thinking about data science and data ethics that is informed by the ideas of intersectional feminism. Today, data science is a form of power. It has been used to expose injustice, improve health outcomes, and topple governments. But it has also been used to discriminate, police, and surveil. This potential for good, on the one hand, and harm, on the other, makes it essential to ask: Data science by whom? Data science for whom? Data science with whose interests in mind? The narratives around big data and data science are overwhelmingly white, male, and techno-heroic. In Data Feminism, Catherine D'Ignazio and Lauren Klein present a new way of thinking about data science and data ethics—one that is informed by intersectional feminist thought. Illustrating data feminism in action, D'Ignazio and Klein show how challenges to the male/female binary can help challenge other hierarchical (and empirically wrong) classification systems. They explain how, for example, an understanding of emotion can expand our ideas about effective data visualization, and how the concept of invisible labor can expose the significant human efforts required by our automated systems. And they show why the data never, ever “speak for themselves.” Data Feminism offers strategies for data scientists seeking to learn how feminism can help them work toward justice, and for feminists who want to focus their efforts on the growing field of data science. But Data Feminism is about much more than gender. It is about power, about who has it and who doesn't, and about how those differentials of power can be challenged and changed.",
#   'dc.language': 'English',
#   'dc.relation.ispartofseries': 'Strong Ideas',
#   'dc.subject.classification': 'bic Book Industry Communication::P Mathematics & science::PD Science: general issues::PDR Impact of science & technology on society',
#   'dc.subject.other': 'intersectionality',
#   'dc.title': 'Data Feminism',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.7551/mitpress/11805.001.0001',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25593',
#   'publisher.contact': 'Terry Ehling',
#   'publisher.name': 'The MIT Press',
#   'publisher.email': 'ehling@mit.edu',
#   'publisher.address': 'One Rogers Street Cambridge, MA 02142 USA',
#   'publisher.country': 'United States',
#   'publisher.website': 'https://mitpress.mit.edu',
#   'publisher.oabooks.exampleUrl': 'https://mitpress.mit.edu/books/street-fighting-mathematics',
#   'publisher.oalicense': 'We usually publish our Open Access titles under a CC BY-NC-ND license, although the licenses do vary title by title. Most OA content is made available in pdf format, with some hosted in html format.',
#   'publisher.peerreviewpolicy': 'MIT Press books undergo independent evaluation and peer review by qualified reviewers in relevant fields. Our peer review practice adheres to the AAUP’s standards as outlined in its Best Practices for Peer Review Handbook.',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://mitpress.mit.edu/open-access',
#   'publisher.chargeauthors': 'N',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1480',
#   'publisher.phone': '001-617-285-0583',
#   'publisher.description': "The MIT Press has been a leader in open access book publishing for two decades, beginning in 1995 with the publication of William Mitchell's City of Bits, which appeared simultaneously in print and in a dynamic, open web edition. We support a variety of open access funding models for select books, including monographs, trade books, and textbooks. <BR> The MIT Press journals division also has a long-standing commitment to open access and makes hundreds of articles free on its website mitpressjournals.org. <BR> All MIT Press subscription journals support author-paid open access (the “hybrid” model). Including three Gold OA journals launching this year, the Press publishes several completely open access journals: Computational Linguistics, Asian Development Review, Open Mind: Discoveries in Cognitive Science, Computational Psychiatry, and Network Neuroscience. <BR> To view our OA book titles, please visit our MIT Pres Open website at https://mitpress.mit.edu/open-access",
#   'oapen.imprint': 'The MIT Press',
#   'oapen.pages': '328',
#   'oapen.place.publication': 'Cambridge'},
#  {'uuid': 'b25e504e-dca3-4d0f-9c86-202a4849012a',
#   'name': 'Data Science in Healthcare',
#   'handle': '20.500.12854/84486',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-06-21 08:38:12.83',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/b25e504e-dca3-4d0f-9c86-202a4849012a',
#   'dc.contributor.editor': 'Hulsen, Tim',
#   'dc.date.accessioned': '2022-06-21T08:38:11Z',
#   'dc.date.available': '2022-06-21T08:38:11Z',
#   'dc.date.issued': '2022',
#   'dc.identifier': 'ONIX_20220621_9783036539836_64',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/84486',
#   'dc.description.abstract': 'Data science is an interdisciplinary field that applies numerous techniques, such as machine learning, neural networks, and deep learning, to create value based on extracting knowledge and insights from available data. Advances in data science have a significant impact on healthcare. While advances in the sharing of medical information result in better and earlier diagnoses as well as more patient-tailored treatments, information management is also affected by trends such as increased patient centricity (with shared decision making), self-care (e.g., using wearables), and integrated care delivery. The delivery of health services is being revolutionized through the sharing and integration of health data across organizational boundaries. Via data science, researchers can deliver new approaches to merge, analyze, and process complex data and gain more actionable insights, understanding, and knowledge at the individual and population levels. This Special Issue focuses on how data science is used in healthcare (e.g., through predictive modeling) and on related topics, such as data sharing and data management.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::M Medicine::MM Other branches of medicine::MMG Pharmacology',
#   'dc.subject.other': 'n/a',
#   'dc.title': 'Data Science in Healthcare',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-3984-3',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
#   'publisher.website': 'www.mdpi.com/books',
#   'publisher.oabooks.exampleUrl': 'http://www.mdpi.com/books/pdfview/book/735',
#   'publisher.oalicense': 'Unless otherwise agreed, edited books (book as a whole) are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY-NC-ND) license. The license allows users to download, copy, and build upon published work non-commercially, as long as the author and publisher are properly credited. If the material is transformed or built upon, the resulting work may not be distributed. The source of the published text must be identified and the DOI of the book should be given. Unless otherwise agreed, articles and monographs are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY) license. The “Open Access” license allows unlimited distribution and reuse as long as appropriate credit is given to the original source and any changes made compared to the original are indicated. The source of the published text must be identified and the DOI of the article should be given.',
#   'publisher.peerreviewpolicy': 'MDPI Books is dedicated to high-quality scholarly publishing. Thus, all manuscripts submitted to MDPI Books are thoroughly reviewed by experts prior to publication. MDPI Books arranges the review process for editions in coordination with the academic editors and coordinates review for monographs with reviewers from the MDPI network. The final decision regarding acceptance of a manuscript lies with the academic editor for Editions and the MDPI Books academic consultant for monographs. <BR><BR> Pre-Check Immediately after submission, manuscripts are checked by MDPI Books editorial staff. You may receive feedback at this stage, prior to peer review. At this stage, checks will be made for plagiarism, data falsification, reuse permissions for figures, inappropriate authorship credit, etc. MDPI takes publishing ethics issues very seriously and adheres to the guidelines of the Committee on Publication Ethics (COPE). <BR><BR> Review All manuscripts submitted to MDPI Books are reviewed by experts from the relevant field. Authors may suggest potential referees with the appropriate expertise, but note that the editors may not necessarily approach these referees. <BR><BR> MDPI aims to provide an efficient and high quality publishing service to authors and to the scientific community. Thus, we ask reviewers to assist by providing review reports in a timely manner—for Editions: several weeks, for monographs: several months. <BR><BR> Authors will typically be asked to revise their manuscript prior to a final editorial decision. <BR> Editor Decision When making an editorial recommendation, reviewers can select from: <BR> accept minor revision major revision reject <BR><BR> The Academic Editor makes an assessment based on the suitability of selected reviewers, the adequacy of reviewer comments and author response, and the overall scientific quality of the paper. <BR><BR> URL: http://www.mdpi.com/books/publish_with_us',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1222',
#   'publisher.phone': '0041 61 683 77 34',
#   'publisher.description': 'With over two decades of academic publishing experience, MDPI is a leader in open access publishing. With its Books Initiative, MDPI also supports new paths in book publishing. MDPI Books offers quality open access book publishing to promote the exchange of ideas and knowledge across all disciplines in a globalized world. MDPI Books encompasses all the benefits of open access—high availability and visibility, as well as wide and rapid dissemination across all book formats. <BR><BR> URL: http://www.mdpi.com/books',
#   'oapen.pages': '212',
#   'oapen.place.publication': 'Basel'},
#  {'uuid': '9c8cfea3-5f30-4b77-8fe1-562a8206dac5',
#   'name': 'Data Science: Measuring Uncertainties',
#   'handle': '20.500.12854/76480',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-02-01 01:50:04.134',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/9c8cfea3-5f30-4b77-8fe1-562a8206dac5',
#   'dc.contributor.editor': 'Rodrigues, Agatha',
#   'dc.date.accessioned': '2022-01-11T13:33:06Z',
#   'dc.date.available': '2022-01-11T13:33:06Z',
#   'dc.date.issued': '2021',
#   'dc.identifier': 'ONIX_20220111_9783036507927_216',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/76480',
#   'dc.description.abstract': 'With the increase in data processing and storage capacity, a large amount of data is available. Data without analysis does not have much value. Thus, the demand for data analysis is increasing daily, and the consequence is the appearance of a large number of jobs and published articles. Data science has emerged as a multidisciplinary field to support data-driven activities, integrating and developing ideas, methods, and processes to extract information from data. This includes methods built from different knowledge areas: Statistics, Computer Science, Mathematics, Physics, Information Science, and Engineering. This mixture of areas has given rise to what we call Data Science. New solutions to the new problems are reproducing rapidly to generate large volumes of data. Current and future challenges require greater care in creating new solutions that satisfy the rationality for each type of problem. Labels such as Big Data, Data Science, Machine Learning, Statistical Learning, and Artificial Intelligence are demanding more sophistication in the foundations and how they are being applied. This point highlights the importance of building the foundations of Data Science. This book is dedicated to solutions and discussions of measuring uncertainties in data analysis problems.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::P Mathematics & science',
#   'dc.subject.other': 'n/a',
#   'dc.title': 'Data Science: Measuring Uncertainties',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-0793-4',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
# ...
#   'dc.contributor.editor': 'Dimitrov, Dimitre',
#   'dc.date.accessioned': '2023-04-05T12:51:32Z',
#   'dc.date.available': '2023-04-05T12:51:32Z',
#   'dc.date.issued': '2023',
#   'dc.identifier': 'ONIX_20230405_9783036566306_73',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/98794',
#   'dc.description.abstract': 'Given the current growth in global challenges, the need for smart agriculture practices and effective strategies is emerging as an imminent issue at a planetary scale. Agriculture 4.0 involves a large variety of mobile apps, web applications, Internet of Things (IoT) devices and platforms, drones, robots, and smart machinery for precision agriculture. The expansion of cloud technologies, artificial intelligence (AI), machine learning (ML), deep learning (DL), and big data collection are setting the stage for Agriculture 5.0. Agriculture science and natural sciences are further promoting this trend with the development of leading-edge scientific models and platforms, including stochastic, process-based, and data-driven machine learning modeling. This Special Issue covers the most recent and up-to-date progress in all aspects of internet and computer software applications in agriculture, focusing on the development of web applications and mobile apps, smart IoT devices and platforms, AI, ML and DL solutions in precision agriculture for detection, recognition, classification, monitoring, cultivation, harvesting, and marketing; development of cloud technologies for smart agriculture; computer and machine vision methods and applications for drones and smart machinery, and sensors for field operations; diagnostics and data collection; big data science; scientific process-based and stochastic modeling; and machine learning modeling for agriculture, agroecosystems and natural ecosystems. The research in this Special Issue will contribute to the promotion of modern agriculture practices in the current climate and in the future.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::T Technology, engineering, agriculture',
#   'dc.subject.other': 'n/a',
#   'dc.title': 'Internet and Computers for Agriculture',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-6631-3',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
#   'publisher.website': 'www.mdpi.com/books',
#   'publisher.oabooks.exampleUrl': 'http://www.mdpi.com/books/pdfview/book/735',
#   'publisher.oalicense': 'Unless otherwise agreed, edited books (book as a whole) are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY-NC-ND) license. The license allows users to download, copy, and build upon published work non-commercially, as long as the author and publisher are properly credited. If the material is transformed or built upon, the resulting work may not be distributed. The source of the published text must be identified and the DOI of the book should be given. Unless otherwise agreed, articles and monographs are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY) license. The “Open Access” license allows unlimited distribution and reuse as long as appropriate credit is given to the original source and any changes made compared to the original are indicated. The source of the published text must be identified and the DOI of the article should be given.',
#   'publisher.peerreviewpolicy': 'MDPI Books is dedicated to high-quality scholarly publishing. Thus, all manuscripts submitted to MDPI Books are thoroughly reviewed by experts prior to publication. MDPI Books arranges the review process for editions in coordination with the academic editors and coordinates review for monographs with reviewers from the MDPI network. The final decision regarding acceptance of a manuscript lies with the academic editor for Editions and the MDPI Books academic consultant for monographs. <BR><BR> Pre-Check Immediately after submission, manuscripts are checked by MDPI Books editorial staff. You may receive feedback at this stage, prior to peer review. At this stage, checks will be made for plagiarism, data falsification, reuse permissions for figures, inappropriate authorship credit, etc. MDPI takes publishing ethics issues very seriously and adheres to the guidelines of the Committee on Publication Ethics (COPE). <BR><BR> Review All manuscripts submitted to MDPI Books are reviewed by experts from the relevant field. Authors may suggest potential referees with the appropriate expertise, but note that the editors may not necessarily approach these referees. <BR><BR> MDPI aims to provide an efficient and high quality publishing service to authors and to the scientific community. Thus, we ask reviewers to assist by providing review reports in a timely manner—for Editions: several weeks, for monographs: several months. <BR><BR> Authors will typically be asked to revise their manuscript prior to a final editorial decision. <BR> Editor Decision When making an editorial recommendation, reviewers can select from: <BR> accept minor revision major revision reject <BR><BR> The Academic Editor makes an assessment based on the suitability of selected reviewers, the adequacy of reviewer comments and author response, and the overall scientific quality of the paper. <BR><BR> URL: http://www.mdpi.com/books/publish_with_us',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1222',
#   'publisher.phone': '0041 61 683 77 34',
#   'publisher.description': 'With over two decades of academic publishing experience, MDPI is a leader in open access publishing. With its Books Initiative, MDPI also supports new paths in book publishing. MDPI Books offers quality open access book publishing to promote the exchange of ideas and knowledge across all disciplines in a globalized world. MDPI Books encompasses all the benefits of open access—high availability and visibility, as well as wide and rapid dissemination across all book formats. <BR><BR> URL: http://www.mdpi.com/books',
#   'oapen.pages': '436',
#   'oapen.place.publication': 'Basel'},
#  {'uuid': 'c831d362-ec71-4ec1-8e86-bf3f40051665',
#   'name': 'Artificial Intelligence Methods Applied to Urban Remote Sensing and GIS',
#   'handle': '20.500.12854/76634',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2022-02-01 01:46:40.232',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/c831d362-ec71-4ec1-8e86-bf3f40051665',
#   'dc.contributor.editor': 'Park, Yu-Chul',
#   'dc.date.accessioned': '2022-01-11T13:37:37Z',
#   'dc.date.available': '2022-01-11T13:37:37Z',
#   'dc.date.issued': '2021',
#   'dc.identifier': 'ONIX_20220111_9783036516042_369',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/76634',
#   'dc.description.abstract': 'This book is based on Special Issue "Artificial Intelligence Methods Applied to Urban Remote Sensing and GIS" from early 2020 to 2021. This book includes seven papers related to the application of artificial intelligence, machine learning and deep learning algorithms using remote sensing and GIS techniques in urban areas.',
#   'dc.language': 'English',
#   'dc.subject.classification': 'bic Book Industry Communication::T Technology, engineering, agriculture::TQ Environmental science, engineering & technology',
#   'dc.subject.other': 'space data science',
#   'dc.title': 'Artificial Intelligence Methods Applied to Urban Remote Sensing and GIS',
#   'dc.type': 'book',
#   'oapen.identifier.doi': '10.3390/books978-3-0365-1603-5',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25340',
#   'publisher.contact': 'Laura Wagner/Nicola Peluchetti',
#   'publisher.name': 'MDPI - Multidisciplinary Digital Publishing Institute',
#   'publisher.email': 'wagner@mdpi.com/MDPI books bookorder@mdpi.com',
#   'publisher.address': 'MDPI St. Alban-Anlage 66 4052 Basel Postfach, CH-4020 Basel Switzerland',
#   'publisher.country': 'Switzerland',
#   'publisher.website': 'www.mdpi.com/books',
#   'publisher.oabooks.exampleUrl': 'http://www.mdpi.com/books/pdfview/book/735',
#   'publisher.oalicense': 'Unless otherwise agreed, edited books (book as a whole) are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY-NC-ND) license. The license allows users to download, copy, and build upon published work non-commercially, as long as the author and publisher are properly credited. If the material is transformed or built upon, the resulting work may not be distributed. The source of the published text must be identified and the DOI of the book should be given. Unless otherwise agreed, articles and monographs are labeled as “Open Access” and licensed by the respective authors in accordance with the Creative Commons Attribution (CC BY) license. The “Open Access” license allows unlimited distribution and reuse as long as appropriate credit is given to the original source and any changes made compared to the original are indicated. The source of the published text must be identified and the DOI of the article should be given.',
#   'publisher.peerreviewpolicy': 'MDPI Books is dedicated to high-quality scholarly publishing. Thus, all manuscripts submitted to MDPI Books are thoroughly reviewed by experts prior to publication. MDPI Books arranges the review process for editions in coordination with the academic editors and coordinates review for monographs with reviewers from the MDPI network. The final decision regarding acceptance of a manuscript lies with the academic editor for Editions and the MDPI Books academic consultant for monographs. <BR><BR> Pre-Check Immediately after submission, manuscripts are checked by MDPI Books editorial staff. You may receive feedback at this stage, prior to peer review. At this stage, checks will be made for plagiarism, data falsification, reuse permissions for figures, inappropriate authorship credit, etc. MDPI takes publishing ethics issues very seriously and adheres to the guidelines of the Committee on Publication Ethics (COPE). <BR><BR> Review All manuscripts submitted to MDPI Books are reviewed by experts from the relevant field. Authors may suggest potential referees with the appropriate expertise, but note that the editors may not necessarily approach these referees. <BR><BR> MDPI aims to provide an efficient and high quality publishing service to authors and to the scientific community. Thus, we ask reviewers to assist by providing review reports in a timely manner—for Editions: several weeks, for monographs: several months. <BR><BR> Authors will typically be asked to revise their manuscript prior to a final editorial decision. <BR> Editor Decision When making an editorial recommendation, reviewers can select from: <BR> accept minor revision major revision reject <BR><BR> The Academic Editor makes an assessment based on the suitability of selected reviewers, the adequacy of reviewer comments and author response, and the overall scientific quality of the paper. <BR><BR> URL: http://www.mdpi.com/books/publish_with_us',
#   'publisher.authorinstructions': 'Y',
#   'publisher.authorinstructions.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.chargeauthors': 'Y',
#   'publisher.chargeauthors.url': 'https://www.mdpi.com/books/publish_with_us',
#   'publisher.register': 'N',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1222',
#   'publisher.phone': '0041 61 683 77 34',
#   'publisher.description': 'With over two decades of academic publishing experience, MDPI is a leader in open access publishing. With its Books Initiative, MDPI also supports new paths in book publishing. MDPI Books offers quality open access book publishing to promote the exchange of ideas and knowledge across all disciplines in a globalized world. MDPI Books encompasses all the benefits of open access—high availability and visibility, as well as wide and rapid dissemination across all book formats. <BR><BR> URL: http://www.mdpi.com/books',
#   'oapen.pages': '165',
#   'oapen.place.publication': 'Basel, Switzerland'},
#  {'uuid': '08fe55e6-7173-486e-bb18-ff66647a8e33',
#   'name': 'Sekundärnutzung von Sozial- und Gesundheitsdaten – Rechtliche Rahmenbedingungen',
#   'handle': '20.500.12854/29491',
#   'type': 'item',
#   'expand': ['parentCollection',
#    'parentCollectionList',
#    'parentCommunityList',
#    'bitstreams',
#    'all'],
#   'lastModified': '2021-02-10 13:32:57.48',
#   'parentCollection': None,
#   'parentCollectionList': None,
#   'parentCommunityList': None,
#   'bitstreams': None,
#   'archived': 'true',
#   'withdrawn': 'false',
#   'link': '/rest/items/08fe55e6-7173-486e-bb18-ff66647a8e33',
#   'dc.contributor.author': 'Roßnagel, Alexander',
#   'dc.date.accessioned': '2021-02-10T13:32:57Z',
#   'dc.date.available': '2021-02-10T13:32:57Z',
#   'dc.date.issued': '2020-02-03',
#   'dc.identifier': 'http://library.oapen.org/handle/20.500.12657/22455',
#   'dc.identifier.uri': 'https://directory.doabooks.org/handle/20.500.12854/29491',
#   'dc.description.abstract': 'Viele der im System der Gesetzlichen Krankenversicherung erhobenen Daten sind für die Weiterentwicklung und Verbesserung der Gesundheitsversorgung von hohem Wert. Sozial- und Gesundheitsdaten sind als personenbezogene Daten aber auch datenschutzrechtlich einem engmaschigen Rechtsrahmen unterworfen. Ihre Nutzung in anderen Kontexten bedarf eines tiefgründigen Verständnisses der Regelungen auf europäischer und nationaler Ebene.\nDieser Band bietet einen Überblick über den aktuellen Rechtsrahmen und eine wichtige Orientierung zur rechtssicheren Nutzung von Sozial- und Gesundheitsdaten. Das Werk ermöglicht es, Lösungen und Produkte zu entwickeln, die die Qualität der Versorgung verbessern. Im ersten Teil wird der sozialrechtliche Rahmen zur Nutzung von Sozialdaten für die Forschung dargelegt. Im zweiten Teil wird ein Überblick zum Umgang mit Forschungsdaten nach Anwendung der DSGVO und entsprechender nationaler Anpassungen des Rechtsrahmens gegeben.',
#   'dc.language': 'German',
#   'dc.rights': 'open access',
#   'dc.subject.classification': 'bic Book Industry Communication::M Medicine::MB Medicine: general issues::MBN Public health & preventive medicine::MBNS Epidemiology & medical statistics',
#   'dc.subject.other': 'data science',
#   'dc.title': 'Sekundärnutzung von Sozial- und Gesundheitsdaten – Rechtliche Rahmenbedingungen',
#   'dc.type': 'book',
#   'oapen.relation.isPublishedBy': 'https://directory.doabooks.org/handle/20.500.12854/25661',
#   'publisher.name': 'MWV Medizinisch Wissenschaftliche Verlagsgesellschaft',
#   'publisher.country': 'Germany',
#   'publisher.status.active': 'true',
#   'publisher.identifier': '1563',
#   'oapen.relation.isFundedBy': 'https://directory.doabooks.org/handle/20.500.12854/39828',
#   'grantor.name': 'Knowledge Unlatched',
#   'oapen.grant.number': '104966',
#   'oapen.grant.program': 'KU Open Services',
#   'dc.dateSubmitted': '2020-04-01T06:51:04Z',
#   'dc.number': '104966',
#   'dc.relationisFundedBy': 'b818ba9d-2dd9-4fd7-a364-7f305aef7ee9',
#   'dc.fundingReference': ''}]

# %%
pd.DataFrame(data)
# Out:
#                                     uuid
# 0   1bf138c9-ac0d-4a66-b7a7-480df06f6361  \
# 1   4bc545b6-6b71-415b-802e-97add94d4e3f
# 2   2538f19b-32c9-45f7-838f-655f6d78127f
# 3   cab18294-da6f-49d7-80f1-f3951f5d70c2
# 4   c55436b4-5501-420a-93e7-3355117d1ed8
# ..                                   ...
# 95  2e41839e-0a98-42bb-bf86-3ade14fc1a4e
# 96  3a272329-38bb-4948-b06e-01807344c7e7
# 97  63bf3d98-fd81-421f-83bb-84fc72a2a1c0
# 98  c831d362-ec71-4ec1-8e86-bf3f40051665
# 99  08fe55e6-7173-486e-bb18-ff66647a8e33
#
#                                                  name              handle
# 0   Data Science, Data Visualization, and Digital ...  20.500.12854/90154  \
# 1   Introduction to Data Science and Machine Learning  20.500.12854/67387
# 2   Collaborative Technologies and Data Science in...  20.500.12854/64403
# 3         Regulatory Data Science for Medical Devices  20.500.12854/81053
# 4         Principles and Applications of Data Science  20.500.12854/87513
# ..                                                ...                 ...
# 95  Recent Advances in Genetics and Breeding of Ma...  20.500.12854/76589
# 96          Complexity in Economic and Social Systems  20.500.12854/76295
# 97             Internet and Computers for Agriculture  20.500.12854/98794
# 98  Artificial Intelligence Methods Applied to Urb...  20.500.12854/76634
# 99  Sekundärnutzung von Sozial- und Gesundheitsdat...  20.500.12854/29491
#
#     type                                             expand
# 0   item  [parentCollection, parentCollectionList, paren...  \
# 1   item  [parentCollection, parentCollectionList, paren...
# 2   item  [parentCollection, parentCollectionList, paren...
# 3   item  [parentCollection, parentCollectionList, paren...
# 4   item  [parentCollection, parentCollectionList, paren...
# ..   ...                                                ...
# 95  item  [parentCollection, parentCollectionList, paren...
# 96  item  [parentCollection, parentCollectionList, paren...
# 97  item  [parentCollection, parentCollectionList, paren...
# 98  item  [parentCollection, parentCollectionList, paren...
# 99  item  [parentCollection, parentCollectionList, paren...
#
#                lastModified parentCollection parentCollectionList
# 0   2022-07-27 08:13:34.118             None                 None  \
# 1   2022-01-31 16:46:25.117             None                 None
# 2   2022-01-31 09:42:15.642             None                 None
# 3   2022-05-06 11:24:47.124             None                 None
# 4    2022-07-06 11:53:51.81             None                 None
# ..                      ...              ...                  ...
# 95  2022-02-01 01:22:31.914             None                 None
# 96  2022-02-01 01:15:05.412             None                 None
# 97  2023-04-05 12:51:33.442             None                 None
# 98  2022-02-01 01:46:40.232             None                 None
# 99   2021-02-10 13:32:57.48             None                 None
#
#    parentCommunityList bitstreams archived withdrawn
# 0                 None       None     true     false  \
# 1                 None       None     true     false
# 2                 None       None     true     false
# 3                 None       None     true     false
# 4                 None       None     true     false
# ..                 ...        ...      ...       ...
# 95                None       None     true     false
# 96                None       None     true     false
# 97                None       None     true     false
# 98                None       None     true     false
# 99                None       None     true     false
#
#                                                 link dc.contributor.editor
# 0   /rest/items/1bf138c9-ac0d-4a66-b7a7-480df06f6361      Shirowzhan, Sara  \
# 1   /rest/items/4bc545b6-6b71-415b-802e-97add94d4e3f      Kadry, Seifedine
# 2   /rest/items/2538f19b-32c9-45f7-838f-655f6d78127f       Luther, Wolfram
# 3   /rest/items/cab18294-da6f-49d7-80f1-f3951f5d70c2      Bergmann, Jeroen
# 4   /rest/items/c55436b4-5501-420a-93e7-3355117d1ed8       Liu, Chuan-Ming
# ..                                               ...                   ...
# 95  /rest/items/2e41839e-0a98-42bb-bf86-3ade14fc1a4e            Yu, Yeisoo
# 96  /rest/items/3a272329-38bb-4948-b06e-01807344c7e7     Oświęcimka, Paweł
# 97  /rest/items/63bf3d98-fd81-421f-83bb-84fc72a2a1c0     Dimitrov, Dimitre
# 98  /rest/items/c831d362-ec71-4ec1-8e86-bf3f40051665         Park, Yu-Chul
# 99  /rest/items/08fe55e6-7173-486e-bb18-ff66647a8e33                   NaN
#
#      dc.date.accessioned     dc.date.available dc.date.issued
# 0   2022-07-27T08:13:33Z  2022-07-27T08:13:33Z           2022  \
# 1   2021-04-20T16:12:18Z  2021-04-20T16:12:18Z           2020
# 2   2021-04-08T15:07:01Z  2021-04-08T15:07:01Z           2020
# 3   2022-05-06T11:24:45Z  2022-05-06T11:24:45Z           2022
# 4   2022-07-06T11:53:50Z  2022-07-06T11:53:50Z           2022
# ..                   ...                   ...            ...
# 95  2022-01-11T13:36:22Z  2022-01-11T13:36:22Z           2021
# 96  2022-01-11T13:27:54Z  2022-01-11T13:27:54Z           2021
# 97  2023-04-05T12:51:32Z  2023-04-05T12:51:32Z           2023
# 98  2022-01-11T13:37:37Z  2022-01-11T13:37:37Z           2021
# 99  2021-02-10T13:32:57Z  2021-02-10T13:32:57Z     2020-02-03
#
#                                         dc.identifier
# 0                      ONIX_20220727_9781839629440_50  \
# 1                    ONIX_20210420_9781838803346_2746
# 2                     ONIX_20210408_9783832551414_102
# 3                     ONIX_20220506_9783036538938_119
# 4                     ONIX_20220706_9783036545271_108
# ..                                                ...
# 95                    ONIX_20220111_9783036509761_324
# 96                     ONIX_20220111_9783036507941_31
# 97                     ONIX_20230405_9783036566306_73
# 98                    ONIX_20220111_9783036516042_369
# 99  http://library.oapen.org/handle/20.500.12657/2...
#
#                                     dc.identifier.uri
# 0   https://directory.doabooks.org/handle/20.500.1...  \
# 1   https://directory.doabooks.org/handle/20.500.1...
# 2   https://directory.doabooks.org/handle/20.500.1...
# 3   https://directory.doabooks.org/handle/20.500.1...
# 4   https://directory.doabooks.org/handle/20.500.1...
# ..                                                ...
# 95  https://directory.doabooks.org/handle/20.500.1...
# 96  https://directory.doabooks.org/handle/20.500.1...
# 97  https://directory.doabooks.org/handle/20.500.1...
# 98  https://directory.doabooks.org/handle/20.500.1...
# 99  https://directory.doabooks.org/handle/20.500.1...
#
#                               dc.description.abstract dc.language
# 0   Real-time, web-based, and interactive visualis...     English  \
# 1   “Introduction to Data Science and Machine Lear...     English
# 2   In September 2020, researchers from Armenia, C...     English
# 3   Regulations that cover the legal obligations t...     English
# 4   Data science is an emerging multidisciplinary ...     English
# ..                                                ...         ...
# 95  To meet the global food demand of an increasin...     English
# 96  There is no term that better describes the ess...     English
# 97  Given the current growth in global challenges,...     English
# 98  This book is based on Special Issue "Artificia...     English
# 99  Viele der im System der Gesetzlichen Krankenve...      German
#
#                             dc.subject.classification
# 0   bic Book Industry Communication::U Computing &...  \
# 1   bic Book Industry Communication::U Computing &...
# 2   bic Book Industry Communication::U Computing &...
# 3   bic Book Industry Communication::T Technology,...
# 4   bic Book Industry Communication::T Technology,...
# ..                                                ...
# 95  bic Book Industry Communication::T Technology,...
# 96  bic Book Industry Communication::K Economics, ...
# 97  bic Book Industry Communication::T Technology,...
# 98  bic Book Industry Communication::T Technology,...
# 99  bic Book Industry Communication::M Medicine::M...
#
#                   dc.subject.other
# 0             Graphics programming  \
# 1                      Data mining
# 2   Smart human centered computing
# 3                              n/a
# 4       crop production prediction
# ..                             ...
# 95          linkage disequilibrium
# 96                             n/a
# 97                             n/a
# 98              space data science
# 99                    data science
#
#                                              dc.title dc.type
# 0   Data Science, Data Visualization, and Digital ...    book  \
# 1   Introduction to Data Science and Machine Learning    book
# 2   Collaborative Technologies and Data Science in...    book
# 3         Regulatory Data Science for Medical Devices    book
# 4         Principles and Applications of Data Science    book
# ..                                                ...     ...
# 95  Recent Advances in Genetics and Breeding of Ma...    book
# 96          Complexity in Economic and Social Systems    book
# 97             Internet and Computers for Agriculture    book
# 98  Artificial Intelligence Methods Applied to Urb...    book
# 99  Sekundärnutzung von Sozial- und Gesundheitsdat...    book
#
#               oapen.identifier.doi
# 0         10.5772/intechopen.87794  \
# 1         10.5772/intechopen.77469
# 2                    10.30819/5141
# 3   10.3390/books978-3-0365-3894-5
# 4   10.3390/books978-3-0365-4528-8
# ..                             ...
# 95  10.3390/books978-3-0365-0977-8
# 96  10.3390/books978-3-0365-0795-8
# 97  10.3390/books978-3-0365-6631-3
# 98  10.3390/books978-3-0365-1603-5
# 99                             NaN
#
#                          oapen.relation.isPublishedBy
# 0   https://directory.doabooks.org/handle/20.500.1...  \
# 1   https://directory.doabooks.org/handle/20.500.1...
# 2   https://directory.doabooks.org/handle/20.500.1...
# 3   https://directory.doabooks.org/handle/20.500.1...
# 4   https://directory.doabooks.org/handle/20.500.1...
# ..                                                ...
# 95  https://directory.doabooks.org/handle/20.500.1...
# 96  https://directory.doabooks.org/handle/20.500.1...
# 97  https://directory.doabooks.org/handle/20.500.1...
# 98  https://directory.doabooks.org/handle/20.500.1...
# 99  https://directory.doabooks.org/handle/20.500.1...
#
#                  publisher.contact
# 0              Slobodan Momčilović  \
# 1              Slobodan Momčilović
# 2                              NaN
# 3   Laura Wagner/Nicola Peluchetti
# 4   Laura Wagner/Nicola Peluchetti
# ..                             ...
# 95  Laura Wagner/Nicola Peluchetti
# 96  Laura Wagner/Nicola Peluchetti
# 97  Laura Wagner/Nicola Peluchetti
# 98  Laura Wagner/Nicola Peluchetti
# 99                             NaN
#
#                                        publisher.name
# 0                                          IntechOpen  \
# 1                                          IntechOpen
# 2                                 Logos Verlag Berlin
# 3   MDPI - Multidisciplinary Digital Publishing In...
# 4   MDPI - Multidisciplinary Digital Publishing In...
# ..                                                ...
# 95  MDPI - Multidisciplinary Digital Publishing In...
# 96  MDPI - Multidisciplinary Digital Publishing In...
# 97  MDPI - Multidisciplinary Digital Publishing In...
# 98  MDPI - Multidisciplinary Digital Publishing In...
# 99  MWV Medizinisch Wissenschaftliche Verlagsgesel...
#
#                                   publisher.email
# 0                               ai@intechopen.com  \
# 1                               ai@intechopen.com
# 2                                             NaN
# 3   wagner@mdpi.com/MDPI books bookorder@mdpi.com
# 4   wagner@mdpi.com/MDPI books bookorder@mdpi.com
# ..                                            ...
# 95  wagner@mdpi.com/MDPI books bookorder@mdpi.com
# 96  wagner@mdpi.com/MDPI books bookorder@mdpi.com
# 97  wagner@mdpi.com/MDPI books bookorder@mdpi.com
# 98  wagner@mdpi.com/MDPI books bookorder@mdpi.com
# 99                                            NaN
#
#                                     publisher.address publisher.country
# 0   IntechOpen Limited The Shard, 25th floor 32 Lo...    United Kingdom  \
# 1   IntechOpen Limited The Shard, 25th floor 32 Lo...    United Kingdom
# 2                                                 NaN               NaN
# 3   MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# 4   MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# ..                                                ...               ...
# 95  MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# 96  MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# 97  MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# 98  MDPI St. Alban-Anlage 66 4052 Basel Postfach, ...       Switzerland
# 99                                                NaN           Germany
#
#               publisher.website
# 0   https://www.intechopen.com/  \
# 1   https://www.intechopen.com/
# 2                           NaN
# 3            www.mdpi.com/books
# 4            www.mdpi.com/books
# ..                          ...
# 95           www.mdpi.com/books
# 96           www.mdpi.com/books
# 97           www.mdpi.com/books
# 98           www.mdpi.com/books
# 99                          NaN
#
#                          publisher.oabooks.exampleUrl
# 0   https://www.intechopen.com/books/infective-end...  \
# 1   https://www.intechopen.com/books/infective-end...
# 2                                                 NaN
# 3          http://www.mdpi.com/books/pdfview/book/735
# 4          http://www.mdpi.com/books/pdfview/book/735
# ..                                                ...
# 95         http://www.mdpi.com/books/pdfview/book/735
# 96         http://www.mdpi.com/books/pdfview/book/735
# 97         http://www.mdpi.com/books/pdfview/book/735
# 98         http://www.mdpi.com/books/pdfview/book/735
# 99                                                NaN
#
#                                   publisher.oalicense
# 0   All published book chapters are licensed under...  \
# 1   All published book chapters are licensed under...
# 2                                                 NaN
# 3   Unless otherwise agreed, edited books (book as...
# 4   Unless otherwise agreed, edited books (book as...
# ..                                                ...
# 95  Unless otherwise agreed, edited books (book as...
# 96  Unless otherwise agreed, edited books (book as...
# 97  Unless otherwise agreed, edited books (book as...
# 98  Unless otherwise agreed, edited books (book as...
# 99                                                NaN
#
#                            publisher.peerreviewpolicy
# 0   Review for Edited Volumes <P> All submitted ma...  \
# 1   Review for Edited Volumes <P> All submitted ma...
# 2                                                 NaN
# 3   MDPI Books is dedicated to high-quality schola...
# 4   MDPI Books is dedicated to high-quality schola...
# ..                                                ...
# 95  MDPI Books is dedicated to high-quality schola...
# 96  MDPI Books is dedicated to high-quality schola...
# 97  MDPI Books is dedicated to high-quality schola...
# 98  MDPI Books is dedicated to high-quality schola...
# 99                                                NaN
#
#    publisher.authorinstructions
# 0                             Y  \
# 1                             Y
# 2                           NaN
# 3                             Y
# 4                             Y
# ..                          ...
# 95                            Y
# 96                            Y
# 97                            Y
# 98                            Y
# 99                          NaN
#
#                      publisher.authorinstructions.url publisher.chargeauthors
# 0   https://www.intechopen.com/how-open-access-pub...                       Y  \
# 1   https://www.intechopen.com/how-open-access-pub...                       Y
# 2                                                 NaN                     NaN
# 3          https://www.mdpi.com/books/publish_with_us                       Y
# 4          https://www.mdpi.com/books/publish_with_us                       Y
# ..                                                ...                     ...
# 95         https://www.mdpi.com/books/publish_with_us                       Y
# 96         https://www.mdpi.com/books/publish_with_us                       Y
# 97         https://www.mdpi.com/books/publish_with_us                       Y
# 98         https://www.mdpi.com/books/publish_with_us                       Y
# 99                                                NaN                     NaN
#
#                           publisher.chargeauthors.url publisher.register
# 0   https://www.intechopen.com/page/OA-publishing-...                  N  \
# 1   https://www.intechopen.com/page/OA-publishing-...                  N
# 2                                                 NaN                NaN
# 3          https://www.mdpi.com/books/publish_with_us                  N
# 4          https://www.mdpi.com/books/publish_with_us                  N
# ..                                                ...                ...
# 95         https://www.mdpi.com/books/publish_with_us                  N
# 96         https://www.mdpi.com/books/publish_with_us                  N
# 97         https://www.mdpi.com/books/publish_with_us                  N
# 98         https://www.mdpi.com/books/publish_with_us                  N
# 99                                                NaN                NaN
#
#    publisher.status.active publisher.identifier    publisher.phone
# 0                     true                 1692   +44 20 8089 5701  \
# 1                     true                 1692   +44 20 8089 5701
# 2                      NaN                  NaN                NaN
# 3                     true                 1222  0041 61 683 77 34
# 4                     true                 1222  0041 61 683 77 34
# ..                     ...                  ...                ...
# 95                    true                 1222  0041 61 683 77 34
# 96                    true                 1222  0041 61 683 77 34
# 97                    true                 1222  0041 61 683 77 34
# 98                    true                 1222  0041 61 683 77 34
# 99                    true                 1563                NaN
#
#                                 publisher.description        oapen.imprint
# 0   Founded in 2004, IntechOpen, the first native ...           IntechOpen  \
# 1   Founded in 2004, IntechOpen, the first native ...           IntechOpen
# 2                                                 NaN  Logos Verlag Berlin
# 3   With over two decades of academic publishing e...                  NaN
# 4   With over two decades of academic publishing e...                  NaN
# ..                                                ...                  ...
# 95  With over two decades of academic publishing e...                  NaN
# 96  With over two decades of academic publishing e...                  NaN
# 97  With over two decades of academic publishing e...                  NaN
# 98  With over two decades of academic publishing e...                  NaN
# 99                                                NaN                  NaN
#
#    oapen.pages oapen.place.publication dc.contributor.author
# 0          116                     NaN                   NaN  \
# 1          232                     NaN                   NaN
# 2          200          Berlin/Germany                   NaN
# 3           76                   Basel                   NaN
# 4          168                   Basel                   NaN
# ..         ...                     ...                   ...
# 95         314      Basel, Switzerland                   NaN
# 96         534      Basel, Switzerland                   NaN
# 97         436                   Basel                   NaN
# 98         165      Basel, Switzerland                   NaN
# 99         NaN                     NaN   Roßnagel, Alexander
#
#    dc.date.submitted dc.relation.ispartofseries    dc.rights
# 0                NaN                        NaN          NaN  \
# 1                NaN                        NaN          NaN
# 2                NaN                        NaN          NaN
# 3                NaN                        NaN          NaN
# 4                NaN                        NaN          NaN
# ..               ...                        ...          ...
# 95               NaN                        NaN          NaN
# 96               NaN                        NaN          NaN
# 97               NaN                        NaN          NaN
# 98               NaN                        NaN          NaN
# 99               NaN                        NaN  open access
#
#    dc.title.alternative         grantor.name grantor.acronym grantor.doi
# 0                   NaN                  NaN             NaN         NaN  \
# 1                   NaN                  NaN             NaN         NaN
# 2                   NaN                  NaN             NaN         NaN
# 3                   NaN                  NaN             NaN         NaN
# 4                   NaN                  NaN             NaN         NaN
# ..                  ...                  ...             ...         ...
# 95                  NaN                  NaN             NaN         NaN
# 96                  NaN                  NaN             NaN         NaN
# 97                  NaN                  NaN             NaN         NaN
# 98                  NaN                  NaN             NaN         NaN
# 99                  NaN  Knowledge Unlatched             NaN         NaN
#
#                             oapen.relation.isFundedBy oapen.grant.number
# 0                                                 NaN                NaN  \
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# ..                                                ...                ...
# 95                                                NaN                NaN
# 96                                                NaN                NaN
# 97                                                NaN                NaN
# 98                                                NaN                NaN
# 99  https://directory.doabooks.org/handle/20.500.1...             104966
#
#                    dc.relationisFundedBy dc.fundingReference
# 0                                    NaN                 NaN  \
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    NaN                 NaN
# ..                                   ...                 ...
# 95                                   NaN                 NaN
# 96                                   NaN                 NaN
# 97                                   NaN                 NaN
# 98                                   NaN                 NaN
# 99  b818ba9d-2dd9-4fd7-a364-7f305aef7ee9
#
#         dc.dateSubmitted oapen.collection dc.number publisher.register.url
# 0                    NaN              NaN       NaN                    NaN  \
# 1                    NaN              NaN       NaN                    NaN
# 2                    NaN              NaN       NaN                    NaN
# 3                    NaN              NaN       NaN                    NaN
# 4                    NaN              NaN       NaN                    NaN
# ..                   ...              ...       ...                    ...
# 95                   NaN              NaN       NaN                    NaN
# 96                   NaN              NaN       NaN                    NaN
# 97                   NaN              NaN       NaN                    NaN
# 98                   NaN              NaN       NaN                    NaN
# 99  2020-04-01T06:51:04Z              NaN    104966                    NaN
#
#    dc.seriesnumber dc.abstractotherlanguage oapen.grant.program
# 0              NaN                      NaN                 NaN  \
# 1              NaN                      NaN                 NaN
# 2              NaN                      NaN                 NaN
# 3              NaN                      NaN                 NaN
# 4              NaN                      NaN                 NaN
# ..             ...                      ...                 ...
# 95             NaN                      NaN                 NaN
# 96             NaN                      NaN                 NaN
# 97             NaN                      NaN                 NaN
# 98             NaN                      NaN                 NaN
# 99             NaN                      NaN    KU Open Services
#
#    dc.grantproject dc.subject dc.description.version
# 0              NaN        NaN                    NaN  \
# 1              NaN        NaN                    NaN
# 2              NaN        NaN                    NaN
# 3              NaN        NaN                    NaN
# 4              NaN        NaN                    NaN
# ..             ...        ...                    ...
# 95             NaN        NaN                    NaN
# 96             NaN        NaN                    NaN
# 97             NaN        NaN                    NaN
# 98             NaN        NaN                    NaN
# 99             NaN        NaN                    NaN
#
#    oapen.abstract.otherlanguage publisher.program publisher.oabooks.number
# 0                           NaN               NaN                      NaN  \
# 1                           NaN               NaN                      NaN
# 2                           NaN               NaN                      NaN
# 3                           NaN               NaN                      NaN
# 4                           NaN               NaN                      NaN
# ..                          ...               ...                      ...
# 95                          NaN               NaN                      NaN
# 96                          NaN               NaN                      NaN
# 97                          NaN               NaN                      NaN
# 98                          NaN               NaN                      NaN
# 99                          NaN               NaN                      NaN
#
#    oapen.edition publisher.peerreview.info oapen.series.number dc.notes
# 0            NaN                       NaN                 NaN      NaN  \
# 1            NaN                       NaN                 NaN      NaN
# 2            NaN                       NaN                 NaN      NaN
# 3            NaN                       NaN                 NaN      NaN
# 4            NaN                       NaN                 NaN      NaN
# ..           ...                       ...                 ...      ...
# 95           NaN                       NaN                 NaN      NaN
# 96           NaN                       NaN                 NaN      NaN
# 97           NaN                       NaN                 NaN      NaN
# 98           NaN                       NaN                 NaN      NaN
# 99           NaN                       NaN                 NaN      NaN
#
#    oapen.relation.isPartOfBook dc.identifier.issn oapen.relation.hasChapter
# 0                          NaN                NaN                       NaN  \
# 1                          NaN                NaN                       NaN
# 2                          NaN                NaN                       NaN
# 3                          NaN                NaN                       NaN
# 4                          NaN                NaN                       NaN
# ..                         ...                ...                       ...
# 95                         NaN                NaN                       NaN
# 96                         NaN                NaN                       NaN
# 97                         NaN                NaN                       NaN
# 98                         NaN                NaN                       NaN
# 99                         NaN                NaN                       NaN
#
#    dc.identifier.pr
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 95              NaN
# 96              NaN
# 97              NaN
# 98              NaN
# 99              NaN
#
# [100 rows x 81 columns]
